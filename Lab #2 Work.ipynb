# %%
# !pwd
# Out:
# /home/jovyan/work/Spring-2018

# %%
# !ls
# Out:
# 00-Syllabus.ipynb			   Assn #1 MCMC.ipynb
# 01-Statistical-Data-Science.ipynb	   candy-data.csv
# 02-Data-and-Uncertainty.ipynb		   Lab #2 Work.ipynb
# 03-Data-collection-and-manipulation.html   Labs
# 03-Data-collection-and-manipulation.ipynb  LICENSE
# Assignment-1.ipynb			   README.md

# %%
! wget https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Out:
# --2018-04-13 16:10:57--  https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.249
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4551 (4.4K) [text/plain]
# Saving to: ‘iris.data’
#
# iris.data           100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2018-04-13 16:10:57 (52.3 MB/s) - ‘iris.data’ saved [4551/4551]

# %%
# !ls
# Out:
# 00-Syllabus.ipynb			   Assignment-1.ipynb  Labs
# 01-Statistical-Data-Science.ipynb	   Assn #1 MCMC.ipynb  LICENSE
# 02-Data-and-Uncertainty.ipynb		   candy-data.csv      README.md
# 03-Data-collection-and-manipulation.html   iris.data
# 03-Data-collection-and-manipulation.ipynb  Lab #2 Work.ipynb

# %%
! ls -F -l # <actual command> -flags/switches/options -argument i.e ls -F -l
# Out:
# total 3608
# -rw-r--r--. 1 jovyan users    4758 Apr 11 18:42 00-Syllabus.ipynb
# -rw-r--r--. 1 jovyan users   21249 Apr 11 18:42 01-Statistical-Data-Science.ipynb
# -rw-r--r--. 1 jovyan users  298252 Apr 11 18:42 02-Data-and-Uncertainty.ipynb
# -rw-r--r--. 1 jovyan users 1718258 Apr 11 18:42 03-Data-collection-and-manipulation.html
# -rw-r--r--. 1 jovyan users 1448029 Apr 11 18:42 03-Data-collection-and-manipulation.ipynb
# -rw-r--r--. 1 jovyan users    4196 Apr 11 18:42 Assignment-1.ipynb
# -rw-r--r--. 1 jovyan users  146340 Apr 13 04:06 Assn #1 MCMC.ipynb
# -rw-r--r--. 1 jovyan users    5205 Apr 11 19:10 candy-data.csv
# -rw-r--r--. 1 jovyan users    4551 Mar  9  1993 iris.data
# -rw-r--r--. 1 jovyan users    2940 Apr 13 16:13 Lab #2 Work.ipynb
# drwxr-xr-x. 2 jovyan users      56 Apr 11 18:42 Labs/
# -rw-r--r--. 1 jovyan users   11357 Apr 11 18:42 LICENSE
# -rw-r--r--. 1 jovyan users     835 Apr 11 18:42 README.md

# %%
! cat iris.data
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
# 4.9,3.0,1.4,0.2,Iris-setosa
# 4.7,3.2,1.3,0.2,Iris-setosa
# 4.6,3.1,1.5,0.2,Iris-setosa
# 5.0,3.6,1.4,0.2,Iris-setosa
# 5.4,3.9,1.7,0.4,Iris-setosa
# 4.6,3.4,1.4,0.3,Iris-setosa
# 5.0,3.4,1.5,0.2,Iris-setosa
# 4.4,2.9,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# 5.4,3.7,1.5,0.2,Iris-setosa
# 4.8,3.4,1.6,0.2,Iris-setosa
# 4.8,3.0,1.4,0.1,Iris-setosa
# 4.3,3.0,1.1,0.1,Iris-setosa
# 5.8,4.0,1.2,0.2,Iris-setosa
# 5.7,4.4,1.5,0.4,Iris-setosa
# 5.4,3.9,1.3,0.4,Iris-setosa
# 5.1,3.5,1.4,0.3,Iris-setosa
# 5.7,3.8,1.7,0.3,Iris-setosa
# 5.1,3.8,1.5,0.3,Iris-setosa
# 5.4,3.4,1.7,0.2,Iris-setosa
# 5.1,3.7,1.5,0.4,Iris-setosa
# 4.6,3.6,1.0,0.2,Iris-setosa
# 5.1,3.3,1.7,0.5,Iris-setosa
# 4.8,3.4,1.9,0.2,Iris-setosa
# 5.0,3.0,1.6,0.2,Iris-setosa
# 5.0,3.4,1.6,0.4,Iris-setosa
# 5.2,3.5,1.5,0.2,Iris-setosa
# 5.2,3.4,1.4,0.2,Iris-setosa
# 4.7,3.2,1.6,0.2,Iris-setosa
# 4.8,3.1,1.6,0.2,Iris-setosa
# 5.4,3.4,1.5,0.4,Iris-setosa
# 5.2,4.1,1.5,0.1,Iris-setosa
# ...

# %%
! head iris.data
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
# 4.9,3.0,1.4,0.2,Iris-setosa
# 4.7,3.2,1.3,0.2,Iris-setosa
# 4.6,3.1,1.5,0.2,Iris-setosa
# 5.0,3.6,1.4,0.2,Iris-setosa
# 5.4,3.9,1.7,0.4,Iris-setosa
# 4.6,3.4,1.4,0.3,Iris-setosa
# 5.0,3.4,1.5,0.2,Iris-setosa
# 4.4,2.9,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa

# %%
! tail iris.data  # recall tab completion type iris.<tab>
# Out:
# 6.9,3.1,5.1,2.3,Iris-virginica
# 5.8,2.7,5.1,1.9,Iris-virginica
# 6.8,3.2,5.9,2.3,Iris-virginica
# 6.7,3.3,5.7,2.5,Iris-virginica
# 6.7,3.0,5.2,2.3,Iris-virginica
# 6.3,2.5,5.0,1.9,Iris-virginica
# 6.5,3.0,5.2,2.0,Iris-virginica
# 6.2,3.4,5.4,2.3,Iris-virginica
# 5.9,3.0,5.1,1.8,Iris-virginica

# %%
! tail -n +6 iris.data # all but the first six data
# Out:
# 5.4,3.9,1.7,0.4,Iris-setosa
# 4.6,3.4,1.4,0.3,Iris-setosa
# 5.0,3.4,1.5,0.2,Iris-setosa
# 4.4,2.9,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# 5.4,3.7,1.5,0.2,Iris-setosa
# 4.8,3.4,1.6,0.2,Iris-setosa
# 4.8,3.0,1.4,0.1,Iris-setosa
# 4.3,3.0,1.1,0.1,Iris-setosa
# 5.8,4.0,1.2,0.2,Iris-setosa
# 5.7,4.4,1.5,0.4,Iris-setosa
# 5.4,3.9,1.3,0.4,Iris-setosa
# 5.1,3.5,1.4,0.3,Iris-setosa
# 5.7,3.8,1.7,0.3,Iris-setosa
# 5.1,3.8,1.5,0.3,Iris-setosa
# 5.4,3.4,1.7,0.2,Iris-setosa
# 5.1,3.7,1.5,0.4,Iris-setosa
# 4.6,3.6,1.0,0.2,Iris-setosa
# 5.1,3.3,1.7,0.5,Iris-setosa
# 4.8,3.4,1.9,0.2,Iris-setosa
# 5.0,3.0,1.6,0.2,Iris-setosa
# 5.0,3.4,1.6,0.4,Iris-setosa
# 5.2,3.5,1.5,0.2,Iris-setosa
# 5.2,3.4,1.4,0.2,Iris-setosa
# 4.7,3.2,1.6,0.2,Iris-setosa
# 4.8,3.1,1.6,0.2,Iris-setosa
# 5.4,3.4,1.5,0.4,Iris-setosa
# 5.2,4.1,1.5,0.1,Iris-setosa
# 5.5,4.2,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# 5.0,3.2,1.2,0.2,Iris-setosa
# 5.5,3.5,1.3,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# ...

# %%
! cut -f 1-3,5 -d , iris.data # head and tail select rows, cut selects columns
# Out:
# 5.1,3.5,1.4,Iris-setosa
# 4.9,3.0,1.4,Iris-setosa
# 4.7,3.2,1.3,Iris-setosa
# 4.6,3.1,1.5,Iris-setosa
# 5.0,3.6,1.4,Iris-setosa
# 5.4,3.9,1.7,Iris-setosa
# 4.6,3.4,1.4,Iris-setosa
# 5.0,3.4,1.5,Iris-setosa
# 4.4,2.9,1.4,Iris-setosa
# 4.9,3.1,1.5,Iris-setosa
# 5.4,3.7,1.5,Iris-setosa
# 4.8,3.4,1.6,Iris-setosa
# 4.8,3.0,1.4,Iris-setosa
# 4.3,3.0,1.1,Iris-setosa
# 5.8,4.0,1.2,Iris-setosa
# 5.7,4.4,1.5,Iris-setosa
# 5.4,3.9,1.3,Iris-setosa
# 5.1,3.5,1.4,Iris-setosa
# 5.7,3.8,1.7,Iris-setosa
# 5.1,3.8,1.5,Iris-setosa
# 5.4,3.4,1.7,Iris-setosa
# 5.1,3.7,1.5,Iris-setosa
# 4.6,3.6,1.0,Iris-setosa
# 5.1,3.3,1.7,Iris-setosa
# 4.8,3.4,1.9,Iris-setosa
# 5.0,3.0,1.6,Iris-setosa
# 5.0,3.4,1.6,Iris-setosa
# 5.2,3.5,1.5,Iris-setosa
# 5.2,3.4,1.4,Iris-setosa
# 4.7,3.2,1.6,Iris-setosa
# 4.8,3.1,1.6,Iris-setosa
# 5.4,3.4,1.5,Iris-setosa
# 5.2,4.1,1.5,Iris-setosa
# 5.5,4.2,1.4,Iris-setosa
# 4.9,3.1,1.5,Iris-setosa
# 5.0,3.2,1.2,Iris-setosa
# 5.5,3.5,1.3,Iris-setosa
# 4.9,3.1,1.5,Iris-setosa
# ...

# %%
! grep "setosa" iris.data
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
# 4.9,3.0,1.4,0.2,Iris-setosa
# 4.7,3.2,1.3,0.2,Iris-setosa
# 4.6,3.1,1.5,0.2,Iris-setosa
# 5.0,3.6,1.4,0.2,Iris-setosa
# 5.4,3.9,1.7,0.4,Iris-setosa
# 4.6,3.4,1.4,0.3,Iris-setosa
# 5.0,3.4,1.5,0.2,Iris-setosa
# 4.4,2.9,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# 5.4,3.7,1.5,0.2,Iris-setosa
# 4.8,3.4,1.6,0.2,Iris-setosa
# 4.8,3.0,1.4,0.1,Iris-setosa
# 4.3,3.0,1.1,0.1,Iris-setosa
# 5.8,4.0,1.2,0.2,Iris-setosa
# 5.7,4.4,1.5,0.4,Iris-setosa
# 5.4,3.9,1.3,0.4,Iris-setosa
# 5.1,3.5,1.4,0.3,Iris-setosa
# 5.7,3.8,1.7,0.3,Iris-setosa
# 5.1,3.8,1.5,0.3,Iris-setosa
# 5.4,3.4,1.7,0.2,Iris-setosa
# 5.1,3.7,1.5,0.4,Iris-setosa
# 4.6,3.6,1.0,0.2,Iris-setosa
# 5.1,3.3,1.7,0.5,Iris-setosa
# 4.8,3.4,1.9,0.2,Iris-setosa
# 5.0,3.0,1.6,0.2,Iris-setosa
# 5.0,3.4,1.6,0.4,Iris-setosa
# 5.2,3.5,1.5,0.2,Iris-setosa
# 5.2,3.4,1.4,0.2,Iris-setosa
# 4.7,3.2,1.6,0.2,Iris-setosa
# 4.8,3.1,1.6,0.2,Iris-setosa
# 5.4,3.4,1.5,0.4,Iris-setosa
# 5.2,4.1,1.5,0.1,Iris-setosa
# ...

# %%
! grep -n -v "setosa" iris.data # -n print line -v invert search i.e return lines that do NOT match setosa
# Out:
# 51:7.0,3.2,4.7,1.4,Iris-versicolor
# 52:6.4,3.2,4.5,1.5,Iris-versicolor
# 53:6.9,3.1,4.9,1.5,Iris-versicolor
# 54:5.5,2.3,4.0,1.3,Iris-versicolor
# 55:6.5,2.8,4.6,1.5,Iris-versicolor
# 56:5.7,2.8,4.5,1.3,Iris-versicolor
# 57:6.3,3.3,4.7,1.6,Iris-versicolor
# 58:4.9,2.4,3.3,1.0,Iris-versicolor
# 59:6.6,2.9,4.6,1.3,Iris-versicolor
# 60:5.2,2.7,3.9,1.4,Iris-versicolor
# 61:5.0,2.0,3.5,1.0,Iris-versicolor
# 62:5.9,3.0,4.2,1.5,Iris-versicolor
# 63:6.0,2.2,4.0,1.0,Iris-versicolor
# 64:6.1,2.9,4.7,1.4,Iris-versicolor
# 65:5.6,2.9,3.6,1.3,Iris-versicolor
# 66:6.7,3.1,4.4,1.4,Iris-versicolor
# 67:5.6,3.0,4.5,1.5,Iris-versicolor
# 68:5.8,2.7,4.1,1.0,Iris-versicolor
# 69:6.2,2.2,4.5,1.5,Iris-versicolor
# 70:5.6,2.5,3.9,1.1,Iris-versicolor
# 71:5.9,3.2,4.8,1.8,Iris-versicolor
# 72:6.1,2.8,4.0,1.3,Iris-versicolor
# 73:6.3,2.5,4.9,1.5,Iris-versicolor
# 74:6.1,2.8,4.7,1.2,Iris-versicolor
# 75:6.4,2.9,4.3,1.3,Iris-versicolor
# 76:6.6,3.0,4.4,1.4,Iris-versicolor
# 77:6.8,2.8,4.8,1.4,Iris-versicolor
# ...

# %%
! grep "setosa" iris.data > setosa.csv # save setosa data to setosa.csv in working directory

# %%
# !ls
# Out:
# 00-Syllabus.ipynb			   Assignment-1.ipynb  Labs
# 01-Statistical-Data-Science.ipynb	   Assn #1 MCMC.ipynb  LICENSE
# 02-Data-and-Uncertainty.ipynb		   candy-data.csv      README.md
# 03-Data-collection-and-manipulation.html   iris.data	       setosa.csv
# 03-Data-collection-and-manipulation.ipynb  Lab #2 Work.ipynb

# %%
! cut -f 1,5 -d , setosa.csv
# Out:
# 5.1,Iris-setosa
# 4.9,Iris-setosa
# 4.7,Iris-setosa
# 4.6,Iris-setosa
# 5.0,Iris-setosa
# 5.4,Iris-setosa
# 4.6,Iris-setosa
# 5.0,Iris-setosa
# 4.4,Iris-setosa
# 4.9,Iris-setosa
# 5.4,Iris-setosa
# 4.8,Iris-setosa
# 4.8,Iris-setosa
# 4.3,Iris-setosa
# 5.8,Iris-setosa
# 5.7,Iris-setosa
# 5.4,Iris-setosa
# 5.1,Iris-setosa
# 5.7,Iris-setosa
# 5.1,Iris-setosa
# 5.4,Iris-setosa
# 5.1,Iris-setosa
# 4.6,Iris-setosa
# 5.1,Iris-setosa
# 4.8,Iris-setosa
# 5.0,Iris-setosa
# 5.0,Iris-setosa
# 5.2,Iris-setosa
# 5.2,Iris-setosa
# 4.7,Iris-setosa
# 4.8,Iris-setosa
# 5.4,Iris-setosa
# 5.2,Iris-setosa
# 5.5,Iris-setosa
# 4.9,Iris-setosa
# 5.0,Iris-setosa
# 5.5,Iris-setosa
# 4.9,Iris-setosa
# 4.4,Iris-setosa
# 5.1,Iris-setosa
# 5.0,Iris-setosa
# 4.5,Iris-setosa
# 4.4,Iris-setosa
# 5.0,Iris-setosa
# 5.1,Iris-setosa
# 4.8,Iris-setosa
# 5.1,Iris-setosa
# 4.6,Iris-setosa
# 5.3,Iris-setosa
# 5.0,Iris-setosa

# %%
! grep "setosa" iris.data | cut -f 1,5 -d , # piping will be easier than creating an entirely new .csv file
# Out:
# 5.1,Iris-setosa
# 4.9,Iris-setosa
# 4.7,Iris-setosa
# 4.6,Iris-setosa
# 5.0,Iris-setosa
# 5.4,Iris-setosa
# 4.6,Iris-setosa
# 5.0,Iris-setosa
# 4.4,Iris-setosa
# 4.9,Iris-setosa
# 5.4,Iris-setosa
# 4.8,Iris-setosa
# 4.8,Iris-setosa
# 4.3,Iris-setosa
# 5.8,Iris-setosa
# 5.7,Iris-setosa
# 5.4,Iris-setosa
# 5.1,Iris-setosa
# 5.7,Iris-setosa
# 5.1,Iris-setosa
# 5.4,Iris-setosa
# 5.1,Iris-setosa
# 4.6,Iris-setosa
# 5.1,Iris-setosa
# 4.8,Iris-setosa
# 5.0,Iris-setosa
# 5.0,Iris-setosa
# 5.2,Iris-setosa
# 5.2,Iris-setosa
# 4.7,Iris-setosa
# 4.8,Iris-setosa
# 5.4,Iris-setosa
# 5.2,Iris-setosa
# 5.5,Iris-setosa
# 4.9,Iris-setosa
# 5.0,Iris-setosa
# 5.5,Iris-setosa
# 4.9,Iris-setosa
# 4.4,Iris-setosa
# 5.1,Iris-setosa
# 5.0,Iris-setosa
# 4.5,Iris-setosa
# 4.4,Iris-setosa
# 5.0,Iris-setosa
# 5.1,Iris-setosa
# 4.8,Iris-setosa
# 5.1,Iris-setosa
# 4.6,Iris-setosa
# 5.3,Iris-setosa
# 5.0,Iris-setosa

# %%
! set
# Out:
# CLICOLOR='1'
# CONDA_DIR='/opt/conda'
# DEBIAN_FRONTEND='noninteractive'
# GIT_PAGER='cat'
# HOME='/home/jovyan'
# HOSTNAME='853f311d37fd'
# IFS='
# '
# JPY_API_TOKEN='db2211edcef749c3bdec06babf46e30f'
# JPY_BASE_URL='/user/b_fox@ucsb.edu/'
# JPY_COOKIE_NAME='cookie'
# JPY_HUB_API_URL='http://jupyterhubserver:8081/hub/api'
# JPY_HUB_PREFIX='/hub/'
# JPY_PARENT_PID='7'
# JPY_USER='b_fox@ucsb.edu'
# JULIA_PKGDIR='/opt/julia'
# JULIA_VERSION='0.6.2'
# JUPYTERHUB_API_TOKEN='db2211edcef749c3bdec06babf46e30f'
# JUPYTERHUB_API_URL='http://bef2ab2ac04f:8081/hub/api'
# JUPYTERHUB_BASE_URL='/'
# JUPYTERHUB_CLIENT_ID='user-b_fox%40ucsb.edu'
# JUPYTERHUB_HOST=''
# JUPYTERHUB_OAUTH_CALLBACK_URL='/user/b_fox@ucsb.edu/oauth_callback'
# JUPYTERHUB_SERVICE_PREFIX='/user/b_fox@ucsb.edu/'
# JUPYTERHUB_USER='b_fox@ucsb.edu'
# LANG='en_US.UTF-8'
# LANGUAGE='en_US.UTF-8'
# LC_ALL='en_US.UTF-8'
# MINICONDA_VERSION='4.3.30'
# MPLBACKEND='module://ipykernel.pylab.backend_inline'
# NB_GID='100'
# ...

# %%
! echo $SHELL # output value of variable
# Out:
# /bin/bash

# %%
# %%bash
# flower_type=$(cut -f 5 -d , iris.data | uniq) # a shell script
# echo $flower_type
# Out:
# Iris-setosa Iris-versicolor Iris-virginica

# %%
# %%bash
# iris_type=$(cut -f 5 -d , iris.data | uniq) # a shell script
# for flower in $iris_type; do grep $flower iris.data > $flower.csv; done # flower is dummy

# %%
# !ls
# Out:
# 00-Syllabus.ipynb			   Iris-setosa.csv
# 01-Statistical-Data-Science.ipynb	   Iris-versicolor.csv
# 02-Data-and-Uncertainty.ipynb		   Iris-virginica.csv
# 03-Data-collection-and-manipulation.html   Lab #2 Work.ipynb
# 03-Data-collection-and-manipulation.ipynb  Labs
# Assignment-1.ipynb			   LICENSE
# Assn #1 MCMC.ipynb			   README.md
# candy-data.csv				   setosa.csv
# iris.data

# %%
! cat Iris-setosa.csv
# Out:
# 5.1,3.5,1.4,0.2,Iris-setosa
# 4.9,3.0,1.4,0.2,Iris-setosa
# 4.7,3.2,1.3,0.2,Iris-setosa
# 4.6,3.1,1.5,0.2,Iris-setosa
# 5.0,3.6,1.4,0.2,Iris-setosa
# 5.4,3.9,1.7,0.4,Iris-setosa
# 4.6,3.4,1.4,0.3,Iris-setosa
# 5.0,3.4,1.5,0.2,Iris-setosa
# 4.4,2.9,1.4,0.2,Iris-setosa
# 4.9,3.1,1.5,0.1,Iris-setosa
# 5.4,3.7,1.5,0.2,Iris-setosa
# 4.8,3.4,1.6,0.2,Iris-setosa
# 4.8,3.0,1.4,0.1,Iris-setosa
# 4.3,3.0,1.1,0.1,Iris-setosa
# 5.8,4.0,1.2,0.2,Iris-setosa
# 5.7,4.4,1.5,0.4,Iris-setosa
# 5.4,3.9,1.3,0.4,Iris-setosa
# 5.1,3.5,1.4,0.3,Iris-setosa
# 5.7,3.8,1.7,0.3,Iris-setosa
# 5.1,3.8,1.5,0.3,Iris-setosa
# 5.4,3.4,1.7,0.2,Iris-setosa
# 5.1,3.7,1.5,0.4,Iris-setosa
# 4.6,3.6,1.0,0.2,Iris-setosa
# 5.1,3.3,1.7,0.5,Iris-setosa
# 4.8,3.4,1.9,0.2,Iris-setosa
# 5.0,3.0,1.6,0.2,Iris-setosa
# 5.0,3.4,1.6,0.4,Iris-setosa
# 5.2,3.5,1.5,0.2,Iris-setosa
# 5.2,3.4,1.4,0.2,Iris-setosa
# 4.7,3.2,1.6,0.2,Iris-setosa
# 4.8,3.1,1.6,0.2,Iris-setosa
# 5.4,3.4,1.5,0.4,Iris-setosa
# 5.2,4.1,1.5,0.1,Iris-setosa
# ...

# %%
! wget https://www.gnu.org/licenses/gpl.txt # regular expression
# Out:
# --2018-04-13 16:47:59--  https://www.gnu.org/licenses/gpl.txt
# Resolving www.gnu.org (www.gnu.org)... 208.118.235.148, 2001:4830:134:3::a
# Connecting to www.gnu.org (www.gnu.org)|208.118.235.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35149 (34K) [text/plain]
# Saving to: ‘gpl.txt’
#
# gpl.txt             100%[===================>]  34.33K  --.-KB/s    in 0.07s
#
# 2018-04-13 16:48:00 (498 KB/s) - ‘gpl.txt’ saved [35149/35149]

# %%
! grep "GNU" gpl.txt # list the lines of the .txt that have GNU in them
# Out:
#                     GNU GENERAL PUBLIC LICENSE
#   The GNU General Public License is a free, copyleft license for
# the GNU General Public License is intended to guarantee your freedom to
# GNU General Public License for most of our software; it applies also to
#   Developers that use the GNU GPL protect your rights with two steps:
#   "This License" refers to version 3 of the GNU General Public License.
#   13. Use with the GNU Affero General Public License.
# under version 3 of the GNU Affero General Public License into a single
# but the special requirements of the GNU Affero General Public License,
# the GNU General Public License from time to time.  Such new versions will
# Program specifies that a certain numbered version of the GNU General
# GNU General Public License, you may choose any version ever published
# versions of the GNU General Public License can be used, that proxy's
#     it under the terms of the GNU General Public License as published by
# ...

# %%
# ^ this is pretty useful
